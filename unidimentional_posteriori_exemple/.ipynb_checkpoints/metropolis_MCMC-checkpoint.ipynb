# %% [markdown]
# ## Definindo funções

# %%
## adapted from https://exowanderer.medium.com/bayes-to-mcmc-with-examples-in-python-4a2da80cc1

from plotly import express as px
from plotly import graph_objs as go

def metropolis_hasting_iterator(curr_state, verbose=False):
    
    proposal = np.random.normal(curr_state, 0.5)
    
    l_curr = np.exp(-curr_state**2 / 2) / np.sqrt(2 * np.pi)
    l_prop = np.exp(-proposal**2 / 2) / np.sqrt(2 * np.pi)
    accept_prob = l_prop / l_curr # max(., 1) ??
    accept_thresh = np.random.uniform(0,1)

    if verbose:
        print(
            proposal,
            l_prop,
            accept_prob,
            accept_thresh,
            accept_prob > accept_thresh
        )

    if accept_prob > accept_thresh:
        return proposal

    return curr_state


def mcmc(initial_state=0, n_samples=1, verbose=False):
    chain = []
    curr_state = initial_state
    for _ in range(n_samples):
        curr_state = metropolis_hasting_iterator(
            curr_state,
            verbose=verbose
        )
        chain.append(curr_state)

    return chain

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_trace(p1, p2, p3, p_name1='parameter', p_name2='parameter', p_name3='parameter'):
  """Plot the trace and posterior of a parameter."""
  
  plt.figure(figsize=(6,11))
    
  # Plotting
    
  plt.subplot(3,1,1)

  mean = np.mean(p1)
  plt.hist(p1, 30, density=True); sns.kdeplot(p1, shade=True)
  plt.xlabel(p_name1)
  plt.ylabel('densidade')
  plt.axvline(mean, color='r', lw=2, linestyle='--',label='média')

  mean = np.mean(p2)
  plt.subplot(3,1,2)
  plt.hist(p2, 30, density=True); sns.kdeplot(p2, shade=True)
  plt.xlabel(p_name2)
  plt.ylabel('densidade')
  plt.axvline(mean, color='r', lw=2, linestyle='--',label='média')

  mean = np.mean(p3)
  plt.subplot(3,1,3)
  plt.hist(p3, 30, density=True); sns.kdeplot(p3, shade=True)
  plt.xlabel(p_name3)
  plt.ylabel('densidade')
  plt.axvline(mean, color='r', lw=2, linestyle='--',label='média')

    
  # plt.savefig("model_1/uniforme_x")

# %%
import numpy as np

np.random.seed(42)
initial_state = 5.0
n_samples = 450

chain = mcmc(
    initial_state=initial_state,
    n_samples=n_samples,
    verbose=False
)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[30], line 7
#       4 initial_state = 5.0
#       5 n_samples = 450
# ----> 7 chain = mcmc(
#       8     initial_state=initial_state,
#       9     n_samples=n_samples,
#      10     verbose=False
#      11 )
#
# Cell In[29], line 56, in mcmc(initial_state, n_samples, verbose)
#      54 curr_state = initial_state
#      55 for _ in range(n_samples):
# ---> 56     curr_state = new_metropolis_hasting_iterator(
#      57         curr_state,
#      58         verbose=verbose
#      59     )
#      60     chain.append(curr_state)
#      62 return chain
#
# Cell In[29], line 35, in new_metropolis_hasting_iterator(curr_state, verbose)
#      33 l_curr = np.exp(-curr_state**2 / 2) / np.sqrt(2 * np.pi)
#      34 l_prop = np.exp(-proposal**2 / 2) / np.sqrt(2 * np.pi)
# ---> 35 accept_prob = np.max(l_prop / l_curr, 1)
#      36 accept_thresh = np.random.uniform(-1,1)
#      38 if verbose:
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84             return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      85         else:
# ---> 86             return reduction(axis=axis, out=out, **passkwargs)
#      88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py:41, in _amax(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
# ---> 41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# AxisError: axis 1 is out of bounds for array of dimension 0

# %%
plot_trace(chain[1:100], chain[1:200], chain[1:450], p_name1='100 amostras', p_name2='200 amostras', p_name3='450 amostras')
# Out:
# /tmp/ipykernel_24313/2295194520.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   plt.hist(p1, 30, density=True); sns.kdeplot(p1, shade=True)
# /tmp/ipykernel_24313/2295194520.py:21: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   plt.hist(p2, 30, density=True); sns.kdeplot(p2, shade=True)
# /tmp/ipykernel_24313/2295194520.py:28: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   plt.hist(p3, 30, density=True); sns.kdeplot(p3, shade=True)

# %%
import matplotlib.pyplot as plt
plt.plot(chain)

# %%
# adapted from https://stackoverflow.com/questions/20011122/fitting-a-normal-distribution-to-1d-data

## fitting data
import matplotlib.pyplot as plt
from scipy.stats import norm

# Fit a normal distribution to the data:
mean = np.mean(chain)
std = np.std(chain)

# Plot the histogram.
plt.hist(chain, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mean, std)
plt.title(title)

plt.show()

# %% [markdown]
# Seja h = x em
# ![image.png](attachment:2af9936f-039c-4af7-97b4-eb0e25ebfbc8.png)
#
# entao o a integral resultante é o valor esperado da normal, e deve ser zero

# %%
approx = sum(chain)/len(chain)
approx
# Out:
# 0.11334456225051126

# %% [markdown]
# ## Calculando posteriori
#
# Agora vou usar a o passeio simulado pra calcular uma posteriori
#
# Considere o problema de calcular $P(\theta | x) = \dfrac{P(x|\theta)\pi(\theta)}{P(x|\theta)}$. Seja a priori $\pi \sim N(1, 1)$
#
# Usando resultados conhecidos do estudo de prioris conjugadas, teremos (no caso de variância $\sigma^2$ dos x conhecida, e de media e variancia $\mu_0$ e $\sigma^2_0$ da priori $\pi(\theta) \sim N(\mu_0, \sigma^2_0)$) $P(\theta|x) \sim N \left(\dfrac{\sigma^2 \mu_0 + nv^2_0 \bar{x}_n}{\sigma^2 + nv^2_0}, \dfrac{\sigma^2 v^2_0}{\sigma^2 + n v^2_0} \right)$

# %% [markdown]
# ![image.png](attachment:9d78e21b-6039-4073-8910-34186d69be88.png)
# ![image.png](attachment:611eda31-ee01-414a-8964-ce4c9133471e.png)

# %% [markdown]
# ## Parâmetros da posteriori conjugada

# %%
## sample parameters
# mean is unknown, but was defined as 0
sigma_square = 1

## priori parameters: theta ~ N(mu_0, v_0_square)
mu_0 = 1
v_0_square = 1


mu_1 = (sigma_square * mu_0 + n_samples*v_0_square * np.mean(chain))/(sigma_square + n_samples*v_0_square)

v_1_square = (sigma_square * v_0_square)/(sigma_square + n_samples * v_0_square)

print("posteriori mean: ", mu_1)
print("posteriori variance", v_1_square)
# Out:
# posteriori mean:  0.11531053883088709
# posteriori variance 0.0022172949002217295

# %%
from sympy import *

from sympy.plotting import plot

x = Symbol('x')
conjugate_posteriori = Function('conjugate_posteriori')

conjugate_posteriori = 1/((v_1_square*2*pi)**(1/2))*exp(-(1/2)*(1/v_1_square)*(x - mu_1)**2)

pn = plot(conjugate_posteriori, (x, -0.2, 0.4),  show=False)
pn.show()

# %% [markdown]
# ## Parâmetros da posteriori via MCMC
#
# Mas se a priori nao fosse conjugada, podemos avaliar a posteriori calculando a verossimilhança dos dados, multiplicando pela priori e normalizando pela marginalização dos dados. O desafio é calcular a marginalização dos dados, e pode ser aproximada usando MCMC:

# %%
from sympy import *

# defining symbols and funtions
theta = Symbol('theta')
Pi = Function('Pi')
L = Function('L')

L = theta**2
2*L

L.subs(theta, 4) 

## aqui tem que cortar coisas que eram só teste
# Out:
# 16

# %%
## defining priori symbolically

Pi = 1/((sigma_square*2*pi)**(1/2))*exp(-(1/2)*(1/sigma_square)*(theta - mu_0)**2)

# %%
from sympy.plotting import plot

p1 = plot(Pi, show=False)
p1.show()

# %%
## defining likelihood symbolically and iteratively
from tqdm import tqdm

L = 1
for element in tqdm(chain):
    L = L * exp((1/(-2*sigma_square))*(element - theta)**2)
L = L * (2*pi*sigma_square)**(-n_samples/2)
# Out:
# 100%|█████████████████████████████████████████| 450/450 [00:04<00:00, 91.57it/s]

# %%
#derivative = L.diff(theta)
#argmax = solve(derivative, theta)

#T = "argmax = " + string(argmax)

#p2 = plot(L, show=False)
#p2.show()

# %%
## integrating marginalization via MCMC

likelihood = []

for i in tqdm(range(1, len(chain))):
    likelihood.append(L.subs(theta, chain[i]))

integral = np.sum(likelihood)/n_samples
# Out:
# 100%|█████████████████████████████████████████| 449/449 [01:35<00:00,  4.71it/s]

# %%
## evaluating posteriori

posteriori = Pi*L/integral

# %%
p3 = plot(posteriori, (theta, -0.2, 0.4), show=False)
p3.show()
